# %%
import pandas as pd

tweet = pd.read_csv('../kaggle_data/merged_tweets.csv',
                       usecols=['ticker_symbol', 'Date', 'body', 'comment_num', 'retweet_num', 'like_num'])
tweet = tweet[(tweet["Date"]>='2019-01-01') & (tweet["Date"]<'2019-12-30')]

# %%
tweets = tweet
tweets["total_engagement"] = tweets["comment_num"] + tweets["retweet_num"] + tweets["like_num"]

# %%
tweets.sort_values(by='Date', ascending=True, inplace=True)
tweets
# Out:
#         ticker_symbol                                               body  \
# 1541845          AAPL  #In2019 I plan to mock the #TrumpTrain relentl...
# 3998103          TSLA  None of those things are possible without fres...
# 3998104          TSLA  $tsla Chicago Westmont update. Open until midn...
# 3998105          TSLA  About 125 $tsla cars remain unsold. Compared t...
# 3998106          TSLA  End of Q push was a bit stronger than expected...
# ...               ...                                                ...
# 1861693          AAPL  Sandro has led his group to multiple great win...
# 1861694          AAPL  Good afternoon ! Let me know if there are any ...
# 1861695          AMZN  Good afternoon ! Let me know if there are any ...
# 1861689          AAPL  Totally normal. Only things that break parabol...
# 4334265          TSLA  Because humans are safer and more acceptable.h...
#
#          comment_num  retweet_num  like_num        Date  total_engagement
# ...

# %%
tweets.to_csv("page1-1.csv", index=False)

# %%
from pysentimiento.preprocessing import preprocess_tweet
from pysentimiento import SentimentAnalyzer

analyzer = SentimentAnalyzer(lang="en")
def cleanUpTweet(txt):
    txt = preprocess_tweet(txt, lang="en", shorten=2)
    return txt

def getOutput(txt):
    return analyzer.predict(txt)

def getProb(output):
    return output.probas[output.output]

def getTextClass(output):
    return output.output

# %%
tweets["clean_text"] = tweets["body"].apply(cleanUpTweet)

# %%
tweets["prob"] = tweets["clean_text"].apply(getOutput).apply(getProb)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tf/kt2z64bn72lfmzbccyrlf4xr0000gn/T/ipykernel_59981/1236615223.py in <module>
# ----> 1 tweets["prob"] = tweets["clean_text"].apply(getOutput).apply(getProb)
#       2
#
# /opt/homebrew/Caskroom/miniforge/base/envs/551proj/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /opt/homebrew/Caskroom/miniforge/base/envs/551proj/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
tweets["tweet_class"] = tweets["clean_text"].apply(getOutput).apply(getTextClass)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tf/kt2z64bn72lfmzbccyrlf4xr0000gn/T/ipykernel_69710/1689144523.py in <module>
# ----> 1 tweets["tweet_class"] = tweets["clean_text"].apply(getOutput).apply(getTextClass)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/551proj/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /opt/homebrew/Caskroom/miniforge/base/envs/551proj/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
import pandas as pd
import re
def cleanUpTweet(txt):
    txt = re.sub(r"@[A−Za−z0−9 ]+", "", txt)
    txt = re.sub(r"#", "", txt)
    txt = re.sub(r"RT ", "", txt)
    txt = re.sub(r"https?:\/\/[A−Za−z0−9\.\/]+", "", txt)
    txt = re.sub(r"www.+", "", txt)
    txt = re.sub(r"pic.twitter.com/+", "", txt)
    # txt = preprocess_tweet(txt, lang="en", shorten=2)
    return txt
tweets = pd.read_csv(f"page1_AAPL.csv")
twitter_data = tweets
twitter_data["clean_text"] = twitter_data["clean_text"].apply(cleanUpTweet)
twitter_data.to_csv("page1_AAPL.csv", index=False)
